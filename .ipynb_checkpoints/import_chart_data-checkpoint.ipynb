# %% [markdown]
# # Get data from image chart

# %% [markdown]
# <img src="example_with_getdata_graph_digitizer.jpg" />

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
df=pd.read_excel('MgCl2-H2O i-xi.xls')
df.rename(columns={'Line #1': 'x1',
                   'Unnamed: 1': 'y1',
                   'Line #2': 'x2',
                   'Unnamed: 4': 'y2',
                   'Line #3': 'x3',
                   'Unnamed: 7': 'y3',
                      }, inplace=True)
df=df[['x1','y1','x2','y2','x3','y3']][1:]
df.reset_index(inplace=True)
df.drop('index',inplace=True,axis=1)
df.head()
# Out:
#          x1         y1        x2         y2        x3         y3
# 0 -0.000353  -0.097848  0.001897  19.047895  0.005019  37.384918
# 1  0.091649 -33.069711  0.002856  18.615078  0.006171  36.979730
# 2  0.090717 -32.629963  0.003760  18.175362  0.007213  36.553781
# 3  0.089011 -32.419100  0.004692  17.735614  0.008172  36.114001
# 4  0.087609 -32.138957  0.005651  17.295834  0.009214  35.688051

# %%
if True:
    x1=df.x1.tolist()
    y1=df.y1.tolist()
    x2=df.x2.tolist()
    y2=df.y2.tolist()
    x3=df.x3.tolist()
    y3=df.y3.tolist()
    plt.figure(figsize=(9,6))
    plt.grid()
    plt.xlabel('Concentration [kg/kg]')
    plt.ylabel('enthalpie [kcal/kg]')
    plt.title('\n MgCl2 Merkel diagramm \n')
    plt.plot(x1, y1)
    plt.plot(x2, y2)
    plt.plot(x3, y3)
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">
